# %% [markdown]
# ### Restore and Check the Model

# %%
import pickle
filename = 'finalized_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))

#heights to check
heights = [[0], [50], [100], [150], [175], [200]]
weights = loaded_model.predict(heights)
print('Input heights: ', heights)
print('Predicted weights are: ', weights)
# Out:
# Input heights:  [[0], [50], [100], [150], [175], [200]]
# Predicted weights are:  [-166.29034128   -1.39346992   13.32603623   41.40189304   56.42986106
#    44.77557652]
# c:\Repos\ml-mod6\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
